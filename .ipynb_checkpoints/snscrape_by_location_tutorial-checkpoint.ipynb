# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
# our search term, using syntax for Twitter's Advanced Search
search = '"data science"'

# the scraped tweets, this is a generator
scraped_tweets = sntwitter.TwitterSearchScraper(search).get_items()

# slicing the generator to keep only the first 100 tweets
sliced_scraped_tweets = itertools.islice(scraped_tweets, 100)

# convert to a DataFrame and keep only relevant columns
df = pd.DataFrame(sliced_scraped_tweets)[['date', 'content']]

df.head()
# Out:
#                        date                                            content
# 0 2020-12-24 14:25:57+00:00  Today's Data Science Daily 📰\n🎄 Making images ...
# 1 2020-12-24 14:24:47+00:00  ARIZONA - THERE WERE 790,175 LAUNDERED VOTES I...
# 2 2020-12-24 14:24:03+00:00  @MCCgov Data Collaboratives for Local Impact (...
# 3 2020-12-24 14:22:25+00:00  2021 Data Science International Scholarships A...
# 4 2020-12-24 14:21:51+00:00  Data science Jobs - https://t.co/IAnJYs1wdH - ...

# %%
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"data science until:2020-12-23"').get_items(), 100))

df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/datascigen/status/13415338...
# 1  https://twitter.com/DataZifu/status/1341533729...
# 2  https://twitter.com/TZaichuk/status/1341532343...
# 3  https://twitter.com/PandhareSidhesh/status/134...
# 4  https://twitter.com/into_AI/status/13415318086...
#
#                        date  \
# 0 2020-12-22 23:59:27+00:00
# 1 2020-12-22 23:59:00+00:00
# 2 2020-12-22 23:53:29+00:00
# 3 2020-12-22 23:51:44+00:00
# 4 2020-12-22 23:51:22+00:00
#
#                                              content  \
# 0  @KatFolland @blowupscheme To this day? Or did ...
# 1  Crossing artificial intelligence thin red line...
# 2  Thank you @tyagi_harshit24 for writing this he...
# 3  Best Laptops for Machine Learning, Data Scienc...
# 4  Data Science / AI / Robotics - With artificial...
#
#                                      renderedContent                   id  \
# 0  @KatFolland @blowupscheme To this day? Or did ...  1341533845640806400
# 1  Crossing artificial intelligence thin red line...  1341533729672466433
# 2  Thank you @tyagi_harshit24 for writing this he...  1341532343513837575
# 3  Best Laptops for Machine Learning, Data Scienc...  1341531902000377862
# 4  Data Science / AI / Robotics - With artificial...  1341531808664612867
#
#                                                 user  \
# 0  {'username': 'datascigen', 'displayname': 'Dat...
# 1  {'username': 'DataZifu', 'displayname': 'Data ...
# 2  {'username': 'TZaichuk', 'displayname': 'Tetia...
# 3  {'username': 'PandhareSidhesh', 'displayname':...
# 4  {'username': 'into_AI', 'displayname': 'Neuron...
#
#                                             outlinks  \
# 0                                                 []
# 1                           [https://bit.ly/2JbGwZQ]
# 2  [https://www.freecodecamp.org/news/statistics-...
# 3  [http://twinybots.ch, https://medium.com/towar...
# 4  [https://neurons.ai/blog/news-stories/data-sci...
#
#                                          tcooutlinks  replyCount  \
# 0                                                 []           1
# 1                          [https://t.co/lwuUSrw9Gx]           0
# 2                          [https://t.co/Rz8c1uNuGO]           0
# 3  [https://t.co/AIFIu0QCMW, https://t.co/oQ5RNbr...           0
# 4                          [https://t.co/CIRMFpMqtL]           0
#
#    retweetCount  ...  quoteCount       conversationId  lang  \
# 0             0  ...           0  1341513905483472900    en
# 1             0  ...           0  1341533729672466433    en
# 2             1  ...           0  1341532343513837575    en
# 3             1  ...           0  1341531902000377862    en
# 4             2  ...           0  1341531808664612867    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="https://hozty.com" rel="nofollow">fit...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twinybots.com" rel="nofollow">...
# 4  <a href="http://into.AI" rel="nofollow">into.A...
#
#                             sourceUrl         sourceLabel media  \
# 0  http://twitter.com/download/iphone  Twitter for iPhone  None
# 1                   https://hozty.com             fitbuzz  None
# 2          https://mobile.twitter.com     Twitter Web App  None
# 3                http://twinybots.com           TwinyBots  None
# 4                      http://into.AI             into.AI  None
#
#   retweetedTweet quotedTweet  \
# 0           None        None
# 1           None        None
# 2           None        None
# 3           None        None
# 4           None        None
#
#                                       mentionedUsers
# 0  [{'username': 'KatFolland', 'displayname': 'ka...
# 1                                               None
# 2  [{'username': 'tyagi_harshit24', 'displayname'...
# 3                                               None
# 4                                               None
#
# [5 rows x 21 columns]

# %%
df_city = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza near:"Los Angeles" within:10km').get_items(), 50))[['date', 'content']]

df_city.head()
# Out:
#                        date                                            content
# 0 2020-12-23 16:15:19+00:00  @vinniLuizLima Nem chego perto, prefiro minha ...
# 1 2020-12-23 16:15:13+00:00  @vicsgl Man pizza q sobra do outro dia é a mel...
# 2 2020-12-23 16:06:00+00:00  @stereogum @timheidecker @theheavyjamz @signif...
# 3 2020-12-23 15:44:00+00:00                        VENDO MI ALMA POR UNA PIZZA
# 4 2020-12-23 15:39:38+00:00  Like I had a breakdown about a damn pizza last...

# %%
loc = '34.052235, -118.243683, 10km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['date', 'content']]

df_coord.head()
# Out:
#                        date                                            content
# 0 2020-12-23 16:15:19+00:00  @vinniLuizLima Nem chego perto, prefiro minha ...
# 1 2020-12-23 16:15:13+00:00  @vicsgl Man pizza q sobra do outro dia é a mel...
# 2 2020-12-23 16:06:00+00:00  @stereogum @timheidecker @theheavyjamz @signif...
# 3 2020-12-23 15:44:00+00:00                        VENDO MI ALMA POR UNA PIZZA
# 4 2020-12-23 15:39:38+00:00  Like I had a breakdown about a damn pizza last...

# %%
common_rows = df_coord.merge(df_city, how='inner')

# %%
loc = '34.052235, -118.243683, 10km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['user', 'date','content']]

df_coord['user_location'] =  df_coord['user'].apply(lambda x: x['location'])

df_coord.head()
# Out:
#                                                 user  \
# 0  {'username': 'BrasilKobe', 'displayname': 'Kob...
# 1  {'username': 'Eduardobingtht', 'displayname': ...
# 2  {'username': 'therealNickJL', 'displayname': '...
# 3  {'username': 'edqueermarisgay', 'displayname':...
# 4  {'username': 'britney_alyse', 'displayname': '...
#
#                        date  \
# 0 2020-12-23 16:15:19+00:00
# 1 2020-12-23 16:15:13+00:00
# 2 2020-12-23 16:06:00+00:00
# 3 2020-12-23 15:44:00+00:00
# 4 2020-12-23 15:39:38+00:00
#
#                                              content    user_location
# 0  @vinniLuizLima Nem chego perto, prefiro minha ...  Los Angeles, CA
# 1  @vicsgl Man pizza q sobra do outro dia é a mel...  Los Angeles, CA
# 2  @stereogum @timheidecker @theheavyjamz @signif...  Los Angeles, CA
# 3                        VENDO MI ALMA POR UNA PIZZA  Los Angeles, CA
# 4  Like I had a breakdown about a damn pizza last...          LA, CA
